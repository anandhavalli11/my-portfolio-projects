# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create sample data
data = {
    "Student": ["Arun", "Divya", "Karthik", "Priya", "Suresh"],
    "Maths": [78, 88, 65, 92, 55],
    "Science": [85, 90, 70, 95, 60],
    "English": [74, 92, 68, 94, 58]
}

df = pd.DataFrame(data)

# Save CSV file
df.to_csv("student_marks.csv", index=False)

# Calculate Total & Average
df["Total"] = df["Maths"] + df["Science"] + df["English"]
df["Average"] = df["Total"] / 3

print(df)

# Subject-wise average
subject_avg = df[["Maths", "Science", "English"]].mean()

# Plot
subject_avg.plot(kind="bar")
plt.title("Average Marks by Subject")
plt.xlabel("Subject")
plt.ylabel("Marks")
plt.show()
# Out:
#    Student  Maths  Science  English  Total    Average
# 0     Arun     78       85       74    237  79.000000
# 1    Divya     88       90       92    270  90.000000
# 2  Karthik     65       70       68    203  67.666667
# 3    Priya     92       95       94    281  93.666667
# 4   Suresh     55       60       58    173  57.666667
